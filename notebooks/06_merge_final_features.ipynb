# %% [markdown]
# # NYC Capital Projects
#
# ## Notebook 06: Merge Engineered Features Into Final NYC Capital Projects Datasets
#
# This notebook merges the cleansed NYC capital projects 3-year interval training and test datasets with the engineered features generated in the prior several notebooks. Those engineered features include the $k$-means-generated reference class labels; the PCA-, autoencoder-, and UMAP-generated 2-dimensional encoded BERT embeddings; and the UMAP+HDBSCAN reference class labels. The resulting merged training and test datasets will be used for predictive modeling in all subsequent notebooks for this project.
#
# ### Project authors
#
# - [An Hoang](https://github.com/hoangthienan95)
# - [Mark McDonald](https://github.com/mcdomx)
# - [Mike Sedelmeyer](https://github.com/sedelmeyer)
#
#
# ### Inputs:
#
# The following files are required to successfully run this notebook.
#
# - ``../data/interim/NYC_capital_projects_3yr_train.csv``
#
#     The training split of our 3-year interval subsetted project data.
#
#
# - ``../data/interim/NYC_capital_projects_3yr_test.csv``
#
#     The test split of our 3-year interval subsetted project data.
#
#
# - ``../data/interim/kmeans3_attribute_labels_train.csv``
#
#     The $k$-means labels corresponding to each project record in our 3-year training split.
#
#
# - ``../data/interim/kmeans3_attribute_labels_test.csv``
#
#     The $k$-means labels corresponding to each project record in our 3-year test split.
#
#
# - ``../data/interim/ae_pca_encoded_embed_train.csv``
#
#     The PCA and autoencoder 2-dimensional feature values corresponding to each project record in our 3-year training split.
#
#
# - ``../data/interim/ae_pca_encoded_embed_test.csv``
#
#     The PCA and autoencoder 2-dimensional feature values corresponding to each project record in our 3-year test split.
#
#
# - ``../data/interim/UMAP_embeddings_NYC_capital_projects_3yr_train.csv``
#
#     The UMAP 2-dimensional encoded embeddings and the UMAP+HDBSCAN reference class cluster labels corresponding to each project record in our 3-year training split.
#
#
# - ``../data/interim/UMAP_embeddings_NYC_capital_projects_3yr_test.csv``
#
#     The UMAP 2-dimensional encoded embeddings and the UMAP+HDBSCAN reference class cluster labels corresponding to each project record in our 3-year test split.
#
#
# ### Outputs:
#
# The following files are generated by executing the code in this notebook.
#
# - ``../data/processed/NYC_capital_projects_3yr_final_train.csv``
#
#     The final training dataset, including all engineered features, for use in subsequent prediction models.
#
#
# - ``../data/processed/NYC_capital_projects_3yr_final_test.csv``
#
#     The final test dataset, including all engineered features, for use in subsequent prediction models.

# %% [markdown]
# # Notebook contents
#
# 1. [Imports](#Imports)
#
# 2. [Read and merge datasets](#Read-and-merge-datasets)
#
# 3. [Save merged datasets](#Save-merged-datasets)
#
# 4. [Print data dictionary for resulting dataset](#Print-data-dictionary-for-resulting-dataset)

# %% [markdown]
# # Imports
#
# [Return to top](#Notebook-contents)

# %%
from functools import reduce
import os

import pandas as pd

import caproj.datagen

# %% [markdown]
# # Read and merge datasets
#
# Load all required datasets and merge all engineered features with the NYC Capital Projects train and test datasets
#
# [Return to top](#Notebook-contents)

# %%
files_needed = set(
    [
        'NYC_capital_projects_3yr_test',
        'NYC_capital_projects_3yr_train',
        'ae_pca_encoded_embed_test',
        'ae_pca_encoded_embed_train',
        'UMAP_embeddings_NYC_capital_projects_3yr_test',
        'UMAP_embeddings_NYC_capital_projects_3yr_train',
        'kmeans3_attribute_labels_test',
        'kmeans3_attribute_labels_train',
    ]
)

files_needed_paths = [f"../data/interim/{file}.csv" for file in files_needed]

savepath_train = "../data/processed/NYC_capital_projects_3yr_final_train.csv"
savepath_test = "../data/processed/NYC_capital_projects_3yr_final_test.csv"

# %%
# check to ensure target files exist to prevent runtime errors
path_errors = []
for filepath in files_needed_paths: 
    if (not os.path.isfile(filepath)) and (not os.path.isdir(filepath)):
        path_errors.append(filepath)
        
if len(path_errors)==0:
    print("OK - all 'files_needed_paths' point to existing files!")

else:
    raise ValueError(
        "The following target paths do not exist...\n\n\t{}\n"\
        "".format(path_errors)
    )
# Out:
# OK - all 'files_needed_paths' point to existing files!

# %%
data_dict = {"train":{}, "test":{}}

print('Dataframes added to data dictionary:\n')

for file in sorted(files_needed_paths):
    file_name, extension = file.split("/")[-1].split(".")
    if file_name.startswith("NYC"):
        date_cols = [
    'Design_Start',
    'Final_Change_Date',
    'Schedule_Start',
    'Schedule_End',
]
        drop_col = "Unnamed: 0"
    
    #umap 
    else:
        date_cols = []
        drop_col = []
    
    df = pd.read_csv(file, parse_dates=date_cols).drop(columns=drop_col)
    
    if file_name.split("_")[-1] == "train":
        data_dict["train"][file_name] = df
    elif file_name.split("_")[-1] == "test":
        data_dict["test"][file_name] = df
    else:
        data_dict[file_name] = df
    
    print(f'\t{file_name}')
# Out:
# Dataframes added to data dictionary:
#
# 	NYC_capital_projects_3yr_test
# 	NYC_capital_projects_3yr_train
# 	UMAP_embeddings_NYC_capital_projects_3yr_test
# 	UMAP_embeddings_NYC_capital_projects_3yr_train
# 	ae_pca_encoded_embed_test
# 	ae_pca_encoded_embed_train
# 	kmeans3_attribute_labels_test
# 	kmeans3_attribute_labels_train

# %%
data_dict["train"].keys()
# Out:
# dict_keys(['NYC_capital_projects_3yr_train', 'UMAP_embeddings_NYC_capital_projects_3yr_train', 'ae_pca_encoded_embed_train', 'kmeans3_attribute_labels_train'])

# %%
data_dict["test"].keys()
# Out:
# dict_keys(['NYC_capital_projects_3yr_test', 'UMAP_embeddings_NYC_capital_projects_3yr_test', 'ae_pca_encoded_embed_test', 'kmeans3_attribute_labels_test'])

# %%
data_dict["train"]['UMAP_embeddings_NYC_capital_projects_3yr_train'].columns[
    data_dict["train"]['UMAP_embeddings_NYC_capital_projects_3yr_train'].columns.str.contains("label")
]
# Out:
# Index(['attribute_clustering_label'], dtype='object')

# %%
# filters so only keep the 2D features
umap_df_train = data_dict["train"]['UMAP_embeddings_NYC_capital_projects_3yr_train']
umap_df_train['attribute_clustering_label'] = umap_df_train['attribute_clustering_label'].astype("str") 
data_dict["train"]['UMAP_embeddings_NYC_capital_projects_3yr_train'] = umap_df_train[
    ["PID"] + list(
        umap_df_train.columns[
            umap_df_train.columns.str.startswith("umap_attributes_2D") | 
            umap_df_train.columns.str.startswith("umap_descr_2D") 
        ]
    ) + ['attribute_clustering_label']
]

# filters so only keep the 2D features
umap_df_test = data_dict["test"]['UMAP_embeddings_NYC_capital_projects_3yr_test']
umap_df_test['attribute_clustering_label'] = umap_df_test['attribute_clustering_label'].astype("str") 
data_dict["test"]['UMAP_embeddings_NYC_capital_projects_3yr_test'] = umap_df_test[
    ["PID"]  + list(
        umap_df_test.columns[
            umap_df_test.columns.str.startswith("umap_attributes_2D") |
            umap_df_test.columns.str.startswith("umap_descr_2D")
        ]
    ) + ['attribute_clustering_label']
]

# %%
df_train_merged = reduce(lambda  left,right: pd.merge(left.copy(),right.copy(),on='PID',
                                            how='left'), data_dict["train"].values())

assert df_train_merged.isnull().sum().sum() == 0
assert df_train_merged.shape == (134,53)

# %%
df_test_merged = reduce(lambda  left,right: pd.merge(left.copy(),right.copy(),on='PID',
                                            how='left'), data_dict["test"].values())

assert df_test_merged.isnull().sum().sum() == 0
assert df_test_merged.shape == (15,53)

# %%
df_train_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 0 to 133
# Data columns (total 53 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PID                         134 non-null    int64
#  1   Project_Name                134 non-null    object
#  2   Description                 134 non-null    object
#  3   Category                    134 non-null    object
#  4   Borough                     134 non-null    object
#  5   Managing_Agency             134 non-null    object
#  6   Client_Agency               134 non-null    object
#  7   Phase_Start                 134 non-null    object
#  8   Current_Project_Years       134 non-null    float64
#  9   Current_Project_Year        134 non-null    int64
#  10  Design_Start                134 non-null    datetime64[ns]
#  11  Budget_Start                134 non-null    float64
#  12  Schedule_Start              134 non-null    datetime64[ns]
#  13  Final_Change_Date           134 non-null    datetime64[ns]
#  14  Final_Change_Years          134 non-null    float64
#  15  Phase_End                   134 non-null    object
#  16  Budget_End                  134 non-null    float64
#  17  Schedule_End                134 non-null    datetime64[ns]
#  18  Number_Changes              134 non-null    int64
#  19  Duration_Start              134 non-null    int64
#  20  Duration_End                134 non-null    int64
#  21  Schedule_Change             134 non-null    int64
#  22  Budget_Change               134 non-null    float64
#  23  Schedule_Change_Ratio       134 non-null    float64
#  24  Budget_Change_Ratio         134 non-null    float64
#  25  Budget_Abs_Per_Error        134 non-null    float64
#  26  Budget_Rel_Per_Error        134 non-null    float64
#  27  Duration_End_Ratio          134 non-null    float64
#  28  Budget_End_Ratio            134 non-null    float64
#  29  Duration_Ratio_Inv          134 non-null    float64
#  30  Budget_Ratio_Inv            134 non-null    float64
#  31  Category_Old                134 non-null    object
#  32  Bridges                     134 non-null    int64
#  33  Ferries                     134 non-null    int64
#  34  Industrial_Development      134 non-null    int64
#  35  Parks                       134 non-null    int64
#  36  Sanitation                  134 non-null    int64
#  37  Schools                     134 non-null    int64
#  38  Sewers                      134 non-null    int64
#  39  Streets_and_Roadways        134 non-null    int64
#  40  Wastewater_Treatment        134 non-null    int64
#  41  Water_Supply                134 non-null    int64
#  42  Category_Code               134 non-null    int64
#  43  umap_descr_2D_embed_1       134 non-null    float64
#  44  umap_descr_2D_embed_2       134 non-null    float64
#  45  umap_attributes_2D_embed_1  134 non-null    float64
#  46  umap_attributes_2D_embed_2  134 non-null    float64
#  47  attribute_clustering_label  134 non-null    object
#  48  ae_descr_embed_1            134 non-null    float64
#  49  ae_descr_embed_2            134 non-null    float64
#  50  pca_descr_embed_1           134 non-null    float64
#  51  pca_descr_embed_2           134 non-null    float64
#  52  attribute_km3_label         134 non-null    int64
# dtypes: datetime64[ns](4), float64(21), int64(18), object(10)
# memory usage: 56.5+ KB

# %%
df_test_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 53 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PID                         15 non-null     int64
#  1   Project_Name                15 non-null     object
#  2   Description                 15 non-null     object
#  3   Category                    15 non-null     object
#  4   Borough                     15 non-null     object
#  5   Managing_Agency             15 non-null     object
#  6   Client_Agency               15 non-null     object
#  7   Phase_Start                 15 non-null     object
#  8   Current_Project_Years       15 non-null     float64
#  9   Current_Project_Year        15 non-null     int64
#  10  Design_Start                15 non-null     datetime64[ns]
#  11  Budget_Start                15 non-null     float64
#  12  Schedule_Start              15 non-null     datetime64[ns]
#  13  Final_Change_Date           15 non-null     datetime64[ns]
#  14  Final_Change_Years          15 non-null     float64
#  15  Phase_End                   15 non-null     object
#  16  Budget_End                  15 non-null     float64
#  17  Schedule_End                15 non-null     datetime64[ns]
#  18  Number_Changes              15 non-null     int64
#  19  Duration_Start              15 non-null     int64
#  20  Duration_End                15 non-null     int64
#  21  Schedule_Change             15 non-null     int64
#  22  Budget_Change               15 non-null     float64
#  23  Schedule_Change_Ratio       15 non-null     float64
#  24  Budget_Change_Ratio         15 non-null     float64
#  25  Budget_Abs_Per_Error        15 non-null     float64
#  26  Budget_Rel_Per_Error        15 non-null     float64
#  27  Duration_End_Ratio          15 non-null     float64
#  28  Budget_End_Ratio            15 non-null     float64
#  29  Duration_Ratio_Inv          15 non-null     float64
#  30  Budget_Ratio_Inv            15 non-null     float64
#  31  Category_Old                15 non-null     object
#  32  Bridges                     15 non-null     int64
#  33  Ferries                     15 non-null     int64
#  34  Industrial_Development      15 non-null     int64
#  35  Parks                       15 non-null     int64
#  36  Sanitation                  15 non-null     int64
#  37  Schools                     15 non-null     int64
#  38  Sewers                      15 non-null     int64
#  39  Streets_and_Roadways        15 non-null     int64
#  40  Wastewater_Treatment        15 non-null     int64
#  41  Water_Supply                15 non-null     int64
#  42  Category_Code               15 non-null     int64
#  43  umap_descr_2D_embed_1       15 non-null     float64
#  44  umap_descr_2D_embed_2       15 non-null     float64
#  45  umap_attributes_2D_embed_1  15 non-null     float64
#  46  umap_attributes_2D_embed_2  15 non-null     float64
#  47  attribute_clustering_label  15 non-null     object
#  48  ae_descr_embed_1            15 non-null     float64
#  49  ae_descr_embed_2            15 non-null     float64
#  50  pca_descr_embed_1           15 non-null     float64
#  51  pca_descr_embed_2           15 non-null     float64
#  52  attribute_km3_label         15 non-null     int64
# dtypes: datetime64[ns](4), float64(21), int64(18), object(10)
# memory usage: 6.3+ KB

# %% [markdown]
# # Save merged datasets
#
# [Return to top](#Notebook-contents)

# %%
df_train_merged.to_csv(savepath_train)
df_test_merged.to_csv(savepath_test)

# %% [markdown]
# # Print data dictionary for resulting dataset
#
# [Return to top](#Notebook-contents)
#
# For ease of reference, printed below is the data dictionary for all features included in the resulting merged dataset.

# %%
caproj.datagen.print_data_dictionary(
    '../references/documentation/data_dict_final_features.csv'
)
# Out:
# DATA DICTIONARY: GENERATED INTERVAL DATASETS
#
# 0: PID (int64)
#
# 	The project identification number
#
#
# 1: Project_Name (object)
#
# 	The name of the project
#
#
# 2: Description (object)
#
# 	A brief written description of the project
#
#
# 3: Category (object)
#
# 	The type of project (i.e. bridges, roadways, schools, etc.)
#
#
# 4: Borough (object)
#
# 	The primary borough location for the project
#
#
# 5: Managing_Agency (object)
#
# 	The primary managing agency for the project
#
#
# 6: Client_Agency (object)
#
# 	The primary client agency for the project
#
#
# 7: Phase_Start (object)
#
# 	The project phase at the time of the first change record recorded
#
#
# 8: Current_Project_Years (float64)
#
# 	The number of years since (in decimal form) the Design_Start date (i.e. the age of the project when the dataset was compiled)
#
#
# 9: Current_Project_Year (int64)
#
# 	The number of years since (in integer form) the Design_Start date
#
#
# 10: Design_Start (datetime64)
#
# 	The date at which the design phase of the project began
#
#
# 11: Budget_Start (float64)
#
# 	The original forecasted budget (in USD) for the project
#
#
# 12: Schedule_Start (datetime64)
#
# 	The original forecasted end date for the project
#
#
# 13: Final_Change_Date (datetime64)
#
# 	The date of the project’s final change record within the time interval being investigated
#
#
# 14: Final_Change_Years (float64)
#
# 	The number of years since (in decimal form) the Design_Start date when the Final_Change_Date was recorded
#
#
# 15: Phase_End (object)
#
# 	The project phase at the time of the last change record recorded within the interval period
#
#
# 16: Budget_End (float64)
#
# 	The final forecasted budget (in USD) for the project at the time of the last change record within the interval period
#
#
# 17: Schedule_End (datetime64)
#
# 	The final forecasted end date for the project at the time of the last change record within the interval period
#
#
# 18: Number_Changes (int64)
#
# 	The total number of change records for the project observed during the interval period
#
#
# 19: Duration_Start (int64)
#
# 	The original forecasted duration (in days) of the project at the time of the earliest available observation
#
#
# 20: Duration_End (int64)
#
# 	The final forecasted duration (in days) of the project at the time of the last change record within the interval period
#
#
# 21: Schedule_Change (int64)
#
# 	The total forecasted duration change (in days) observed during the interval period: Duration_End -Duration_Start
#
#
# 22: Budget_Change (float64)
#
# 	The total forecasted budget change (in USD) observed during the interval period: Budget_End - Budget_Start
#
#
# 23: Schedule_Change_Ratio (float64)
#
# 	Change metric: Schedule Change / Duration_Start
#
#
# 24: Budget_Change_Ratio (float64)
#
# 	Change metric: Budget_Change / Budget_Start
#
#
# 25: Budget_Abs_Per_Error (float64)
#
# 	Change metric: (Budget_Start – Budget_End) / Budget_End
#
#
# 26: Budget_Rel_Per_Error (float64)
#
# 	Change metric: (Budget_Start – Budget_End) / Budget_Start
#
#
# 27: Duration_End_Ratio (float64)
#
# 	Change metric: Duration_End / Duration_Start
#
#
# 28: Budget_End_Ratio (float64)
#
# 	Change metric: Budget_End / Budget_Start
#
#
# 29: Duration_Ratio_Inv (float64)
#
# 	Change metric: (Duration_Start / Duration_End) - 1
#
#
# 30: Budget_Ratio_Inv (float64)
#
# 	Change metric: (Budget_Start / Budget_End) - 1
#
#
# 31: Category_Old (object)
#
# 	The original Category values for each project prior to consolidating categories
#
#
# 32: Bridges (int64)
#
# 	The one-hot-encoded Bridges project Category
#
#
# 33: Ferries (int64)
#
# 	The one-hot-encoded Ferries project Category
#
#
# 34: Industrial_Development (int64)
#
# 	The one-hot-encoded Industrial_Development project Category
#
#
# 35: Parks (int64)
#
# 	The one-hot-encoded Parks project Category
#
#
# 36: Sanitation (int64)
#
# 	The one-hot-encoded Sanitation project Category
#
#
# 37: Schools (int64)
#
# 	The one-hot-encoded Schools project Category
#
#
# 38: Sewers (int64)
#
# 	The one-hot-encoded Sewers project Category
#
#
# 39: Streets_and_Roadways (int64)
#
# 	The one-hot-encoded Streets_and_Roadways project Category
#
#
# 40: Wastewater_Treatment (int64)
#
# 	The one-hot-encoded Wastewater_Treatment project Category
#
#
# 41: Water_Supply (int64)
#
# 	The one-hot-encoded Water_Supply project Category
#
#
# 42: Category_Code (int64)
#
# 	The Category values label-encoded as integers rather than one-hot-encoded
#
#
# 43: umap_descr_2D_embed_1 (float64)
#
# 	The first of two dimensions for the dimension-reduced BERT embeddings using the UMAP algorithm
#
#
# 44: umap_descr_2D_embed_2 (float64)
#
# 	The second of two dimensions for the dimension-reduced BERT embeddings using the UMAP algorithm
#
#
# 45: umap_attributes_2D_embed_1 (float64)
#
# 	The first of two dimensions for the dimension-reduced BERT embeddings plus the initial project attributes using the UMAP algorithm
#
#
# 46: umap_attributes_2D_embed_2 (float64)
#
# 	The second of two dimensions for the dimension-reduced BERT embeddings plus the initial project attributes using the UMAP algorithm
#
#
# 47: attribute_clustering_label (int64)
#
# 	The unsupervised clustering labels for each project using UMAP followed by HDSCAN on all initial project attributes
#
#
# 48: ae_descr_embed_1 (float64)
#
# 	The first of two dimensions for the dimension-reduced BERT embeddings using the encoded space of a dense autoencoder network
#
#
# 49: ae_descr_embed_2 (float64)
#
# 	The second of two dimensions for the dimension-reduced BERT embeddings using the encoded space of a dense autoencoder network
#
#
# 50: pca_descr_embed_1 (float64)
#
# 	The first of two dimensions for the dimension-reduced BERT embeddings using principal component analysis (PCA)
#
#
# 51: pca_descr_embed_2 (float64)
#
# 	The second of two dimensions for the dimension-reduced BERT embeddings using principal component analysis (PCA)
#
#
# 52: attribute_km3_label (int64)
#
# 	The unsupervised clustering labels for each project using K-means of k=3 on all initial project attributes
