# %% [markdown]
# # Notebook 03a: K-means Attribute Clusters
#
# Identifying baseline project reference classes with unsupervised clustering.
#
#
# ### Inputs:
#
# 1. **`../data/processed/NYC_capital_projects_3yr_train.csv`**
#
#
# 2. **`../data/processed/NYC_capital_projects_3yr_train.csv`**
#
#
# 3. **`../data/interim/NYC_capital_projects_3yr.csv`**
#
#
# ### Outputs:
#
# 1. **`../models/kmeans3_attribute_labels.pickle`** (this is the fitted `KMeans` scikit-learn model)
#
#
# 2. **`../data/interim/kmeans3_attribute_labels_train.csv`**
#
#
#
# 3. **`../data/interim/kmeans3_attribute_labels_test.csv`**

# %% [markdown]
# <a name='index'></a>
#
# # Contents of this notebook
#
#
# 1. [Import libraries and load data](#Import-libraries-and-load-data)
#
# 2. [One hot encode categorical varables](#One-hot-encode-categorical-varables)
#
# 3. [Subset and scale X and y frames](#Subset-and-scale-X-and-y-frames)
#
# 4. [Inspect k-means clustering](#Inspect-k-means-clustering)
#
# 5. [Check results against DBSCAN](#Check-results-against-DBSCAN)
#
# 6. [Check results against a Ward Method Dendrogram](#Check-results-against-a-Ward-Method-Dendrogram)
#
# 7. [Findings](#Findings)
#
# 8. [Save resulting k-means labels and model](#Save-resulting-k-means-labels-and-model)

# %% [markdown]
# # Import libraries and load data
#
# [Return to top](#Contents-of-this-notebook)

# %%
import os
import sys
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler, \
                                  RobustScaler, LabelEncoder

# clustering specific imports
from sklearn.cluster import KMeans
from gap_statistic import OptimalK
from sklearn.decomposition import PCA
import scipy.cluster.hierarchy as hac
from scipy.spatial.distance import pdist
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_samples, silhouette_score


# import custom .py functions from caproj module
from caproj.datagen import print_interval_dict
from caproj.scale import scale_features, sigmoid, log_plus_one, encode_categories
from caproj.model import generate_model_dict, print_model_results
from caproj.visualize import plot_true_pred, plot_bdgt_sched_scaled, \
                          plot_change_trend, plot_line
from caproj.cluster import silplot, display_gapstat_with_errbars, \
                        fit_neighbors, plot_epsilon, silscore_dbscan, \
                        fit_dbscan, print_dbscan_results

# Avoid scientific notation output in Pandas
# pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.options.display.float_format = '{:,.2f}'.format

# Improve resolution of output graphics
# %config InlineBackend.figure_format ='retina'

# %%
filepath_train = '../data/interim/NYC_capital_projects_3yr_train.csv'
filepath_test = '../data/interim/NYC_capital_projects_3yr_test.csv'

filepath_data = '../data/interim/NYC_capital_projects_3yr.csv'

savedata_train = '../data/interim/kmeans3_attribute_labels_train.csv'
savedata_test = '../data/interim/kmeans3_attribute_labels_test.csv'
savemodel = '../models/kmeans3_attribute_labels.pickle'

if os.path.isfile(filepath_train):
    print("OK - path points to file.")
else:
    print("ERROR - check the 'file_path' and ensure it points to the source file.")
# Out:
# OK - path points to file.

# %%
data = pd.read_csv(filepath_data)
data_train = pd.read_csv(filepath_train)
data_test = pd.read_csv(filepath_test)
data_full = pd.read_csv('../data/interim/Capital_Projects_clean.csv')

# %%
# entries
print(f"Number of dataset records: {len(data)}")

# num projects
print(f"Number of unique projects in dataset: {len(data['PID'].unique())}")
# Out:
# Number of dataset records: 149
# Number of unique projects in dataset: 149

# %%
data_train.shape, data_test.shape
# Out:
# ((134, 44), (15, 44))

# %%
datetime_cols = [
    'Design_Start',
    'Final_Change_Date',
    'Schedule_Start',
    'Schedule_End',
]

for col in datetime_cols:
    data[col] = pd.to_datetime(data[col])
    data_train[col] = pd.to_datetime(data_train[col])
    data_test[col] = pd.to_datetime(data_test[col])

# %%
data.info()

data.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PID                    149 non-null    int64
#  1   Project_Name           149 non-null    object
#  2   Description            149 non-null    object
#  3   Category               149 non-null    object
#  4   Borough                149 non-null    object
#  5   Managing_Agency        149 non-null    object
#  6   Client_Agency          149 non-null    object
#  7   Phase_Start            149 non-null    object
#  8   Current_Project_Years  149 non-null    float64
#  9   Current_Project_Year   149 non-null    int64
#  10  Design_Start           149 non-null    datetime64[ns]
#  11  Budget_Start           149 non-null    float64
#  12  Schedule_Start         149 non-null    datetime64[ns]
#  13  Final_Change_Date      149 non-null    datetime64[ns]
#  14  Final_Change_Years     149 non-null    float64
#  15  Phase_End              149 non-null    object
#  16  Budget_End             149 non-null    float64
#  17  Schedule_End           149 non-null    datetime64[ns]
#  18  Number_Changes         149 non-null    int64
#  19  Duration_Start         149 non-null    int64
#  20  Duration_End           149 non-null    int64
#  21  Schedule_Change        149 non-null    int64
#  22  Budget_Change          149 non-null    float64
#  23  Schedule_Change_Ratio  149 non-null    float64
#  24  Budget_Change_Ratio    149 non-null    float64
#  25  Budget_Abs_Per_Error   149 non-null    float64
#  26  Budget_Rel_Per_Error   149 non-null    float64
#  27  Duration_End_Ratio     149 non-null    float64
#  28  Budget_End_Ratio       149 non-null    float64
#  29  Duration_Ratio_Inv     149 non-null    float64
#  30  Budget_Ratio_Inv       149 non-null    float64
# dtypes: datetime64[ns](4), float64(13), int64(6), object(8)
# memory usage: 36.2+ KB
#    PID                                       Project_Name  \
# 0    3  26th Ward Waste Water Treatment Plant Prelimin...
# 1    7  Bowery Bay Waste Water Treatment Plant Main Se...
# 2   91                      Mill Basin Bridge Replacement
#
#                                          Description              Category  \
# 0  The 26th Ward WWTP is mandated to be upgraded ...  Wastewater Treatment
# 1  The existing Main Sewage Pumps have deteriorat...  Wastewater Treatment
# 2  Complete replacement of bascule bridge with a ...               Bridges
#
#     Borough Managing_Agency  Client_Agency Phase_Start  Current_Project_Years  \
# 0  Brooklyn             DEP            DEP    2-Design                   5.94
# 1    Queens             DEP            DEP    2-Design                   6.34
# 2  Brooklyn             DOT  not_specified    2-Design                   7.44
#
#    Current_Project_Year  ... Schedule_Change  Budget_Change  \
# 0                     6  ...              91 -15,619,967.29
# 1                     7  ...             334   9,618,785.30
# 2                     8  ...             247 -34,672,662.00
#
#   Schedule_Change_Ratio Budget_Change_Ratio  Budget_Abs_Per_Error  \
# 0                  0.04               -0.08                  0.09
# 1                  0.19                0.18                  0.15
# 2                  0.09               -0.09                  0.10
#
#   Budget_Rel_Per_Error  Duration_End_Ratio Budget_End_Ratio  \
# 0                 0.08                1.04             0.92
# 1                 0.18                1.19             1.18
# 2                 0.09                1.09             0.91
#
#    Duration_Ratio_Inv  Budget_Ratio_Inv
# 0               -0.04              0.09
# 1               -0.16             -0.15
# 2               -0.08              0.10
#
# [3 rows x 31 columns]

# %% [markdown]
# # One hot encode categorical varables
#
# [Return to top](#Contents-of-this-notebook)

# %%
list_cols = list(data.columns)
list_cols[3:12]
# Out:
# ['Category',
#  'Borough',
#  'Managing_Agency',
#  'Client_Agency',
#  'Phase_Start',
#  'Current_Project_Years',
#  'Current_Project_Year',
#  'Design_Start',
#  'Budget_Start']

# %%
X_cols = [
    'PID',
    'Category',
    'Borough',
    'Managing_Agency',
    'Client_Agency',
    'Phase_Start',
    'Budget_Start',
    'Duration_Start'
]

# %%
X = data[X_cols].set_index('PID')
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 3 to 1004
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Category         149 non-null    object
#  1   Borough          149 non-null    object
#  2   Managing_Agency  149 non-null    object
#  3   Client_Agency    149 non-null    object
#  4   Phase_Start      149 non-null    object
#  5   Budget_Start     149 non-null    float64
#  6   Duration_Start   149 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 9.3+ KB

# %%
print('{}\n\n'.format(data['Category'].value_counts()))
print('{}\n\n'.format(data['Managing_Agency'].value_counts()))
print('{}\n\n'.format(data['Client_Agency'].value_counts()))
print('{}\n\n'.format(data['Borough'].value_counts()))
print('{}\n\n'.format(data['Phase_Start'].value_counts()))
# Out:
# Streets and Roadways                  31
# Sewers                                20
# Schools                               15
# Industrial Development                15
# Water Supply                          13
# Wastewater Treatment                  13
# Bridges, Streets and Roadways          9
# Bridges                                7
# Sanitation                             6
# Other Government Facilities            4
# Public Safety and Criminal Justice     4
# Health and Hospitals                   3
# Ferries                                3
# Arts and Culture                       2
# Parks                                  2
# Industrial Development, Parks          1
# Parks, Streets and Roadways            1
# Name: Category, dtype: int64
#
#
# DDC     63
# DOT     34
# DEP     19
# SCA     15
# EDC     14
# DCAS     2
# DSNY     2
# Name: Managing_Agency, dtype: int64
#
#
# DEP                    53
# not_specified          35
# DOT                    17
# DOE                    15
# DSNY                    7
# DCAS                    4
# H+H                     3
# DPR                     3
# DCLA                    2
# DOHMH, HHC              1
# DEP, EDC                1
# NYPD                    1
# Mayor's Office          1
# EDC                     1
# DHS                     1
# ORR                     1
# DSBS                    1
# DOT, Mayor's Office     1
# BWS                     1
# Name: Client_Agency, dtype: int64
#
#
# not_specified                      47
# Brooklyn                           30
# Queens                             19
# Manhattan                          17
# Bronx                              12
# Staten Island                       9
# Citywide                            5
# New York                            2
# Valhalla                            2
# Manhattan, Bronx                    1
# Manhattan, Staten Island, Bronx     1
# Olive                               1
# Port Jervis                         1
# Brooklyn, Queens                    1
# Marlboro                            1
# Name: Borough, dtype: int64
#
#
# 2-Design                      114
# 3-Construction Procurement     25
# 4-Construction                 10
# Name: Phase_Start, dtype: int64

# %%
# One hot encode categorical variables
drop_cat = 'Other Government Facilities'
one_hot = True

X = encode_categories(
    X, colname='Category',
    one_hot=one_hot,
    drop_cat=drop_cat,
    drop_original_col=True,
    append_colname='cat'
)

drop_cat = 'DSNY'
one_hot = True

X = encode_categories(
    X, colname='Managing_Agency',
    one_hot=one_hot,
    drop_cat=drop_cat,
    drop_original_col=True,
    append_colname='manag'
)

drop_cat = 'not_specified'
one_hot = True

X = encode_categories(
    X, colname='Client_Agency',
    one_hot=one_hot,
    drop_cat=drop_cat,
    drop_original_col=True,
    append_colname='cliag'
)

drop_cat = 'not_specified'
one_hot = True

X = encode_categories(
    X, colname='Borough',
    one_hot=one_hot,
    drop_cat=drop_cat,
    drop_original_col=True,
    append_colname='bor'
)

drop_cat = '4-Construction'
one_hot = True

X = encode_categories(
    X, colname='Phase_Start',
    one_hot=one_hot,
    drop_cat=drop_cat,
    drop_original_col=True
)

X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 3 to 1004
# Data columns (total 58 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Budget_Start                            149 non-null    float64
#  1   Duration_Start                          149 non-null    int64
#  2   cat_Arts_and_Culture                    149 non-null    uint8
#  3   cat_Bridges                             149 non-null    uint8
#  4   cat_Bridges,_Streets_and_Roadways       149 non-null    uint8
#  5   cat_Ferries                             149 non-null    uint8
#  6   cat_Health_and_Hospitals                149 non-null    uint8
#  7   cat_Industrial_Development              149 non-null    uint8
#  8   cat_Industrial_Development,_Parks       149 non-null    uint8
#  9   cat_Parks                               149 non-null    uint8
#  10  cat_Parks,_Streets_and_Roadways         149 non-null    uint8
#  11  cat_Public_Safety_and_Criminal_Justice  149 non-null    uint8
#  12  cat_Sanitation                          149 non-null    uint8
#  13  cat_Schools                             149 non-null    uint8
#  14  cat_Sewers                              149 non-null    uint8
#  15  cat_Streets_and_Roadways                149 non-null    uint8
#  16  cat_Wastewater_Treatment                149 non-null    uint8
#  17  cat_Water_Supply                        149 non-null    uint8
#  18  manag_DCAS                              149 non-null    uint8
#  19  manag_DDC                               149 non-null    uint8
#  20  manag_DEP                               149 non-null    uint8
#  21  manag_DOT                               149 non-null    uint8
#  22  manag_EDC                               149 non-null    uint8
#  23  manag_SCA                               149 non-null    uint8
#  24  cliag_BWS                               149 non-null    uint8
#  25  cliag_DCAS                              149 non-null    uint8
#  26  cliag_DCLA                              149 non-null    uint8
#  27  cliag_DEP                               149 non-null    uint8
#  28  cliag_DEP,_EDC                          149 non-null    uint8
#  29  cliag_DHS                               149 non-null    uint8
#  30  cliag_DOE                               149 non-null    uint8
#  31  cliag_DOHMH,_HHC                        149 non-null    uint8
#  32  cliag_DOT                               149 non-null    uint8
#  33  cliag_DOT,_Mayor's_Office               149 non-null    uint8
#  34  cliag_DPR                               149 non-null    uint8
#  35  cliag_DSBS                              149 non-null    uint8
#  36  cliag_DSNY                              149 non-null    uint8
#  37  cliag_EDC                               149 non-null    uint8
#  38  cliag_H+H                               149 non-null    uint8
#  39  cliag_Mayor's_Office                    149 non-null    uint8
#  40  cliag_NYPD                              149 non-null    uint8
#  41  cliag_ORR                               149 non-null    uint8
#  42  bor_Bronx                               149 non-null    uint8
#  43  bor_Brooklyn                            149 non-null    uint8
#  44  bor_Brooklyn,_Queens                    149 non-null    uint8
#  45  bor_Citywide                            149 non-null    uint8
#  46  bor_Manhattan                           149 non-null    uint8
#  47  bor_Manhattan,_Bronx                    149 non-null    uint8
#  48  bor_Manhattan,_Staten_Island,_Bronx     149 non-null    uint8
#  49  bor_Marlboro                            149 non-null    uint8
#  50  bor_New_York                            149 non-null    uint8
#  51  bor_Olive                               149 non-null    uint8
#  52  bor_Port_Jervis                         149 non-null    uint8
#  53  bor_Queens                              149 non-null    uint8
#  54  bor_Staten_Island                       149 non-null    uint8
#  55  bor_Valhalla                            149 non-null    uint8
#  56  2-Design                                149 non-null    uint8
#  57  3-Construction_Procurement              149 non-null    uint8
# dtypes: float64(1), int64(1), uint8(56)
# memory usage: 11.6 KB

# %% [markdown]
# # Subset and scale X and y frames
#
# [Return to top](#Contents-of-this-notebook)

# %%
X_train_pids = data_train['PID'].values
X_test_pids = data_test['PID'].values

X_train, X_test = X.loc[X_train_pids], X.loc[X_test_pids]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 204 to 113
# Data columns (total 58 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Budget_Start                            134 non-null    float64
#  1   Duration_Start                          134 non-null    int64
#  2   cat_Arts_and_Culture                    134 non-null    uint8
#  3   cat_Bridges                             134 non-null    uint8
#  4   cat_Bridges,_Streets_and_Roadways       134 non-null    uint8
#  5   cat_Ferries                             134 non-null    uint8
#  6   cat_Health_and_Hospitals                134 non-null    uint8
#  7   cat_Industrial_Development              134 non-null    uint8
#  8   cat_Industrial_Development,_Parks       134 non-null    uint8
#  9   cat_Parks                               134 non-null    uint8
#  10  cat_Parks,_Streets_and_Roadways         134 non-null    uint8
#  11  cat_Public_Safety_and_Criminal_Justice  134 non-null    uint8
#  12  cat_Sanitation                          134 non-null    uint8
#  13  cat_Schools                             134 non-null    uint8
#  14  cat_Sewers                              134 non-null    uint8
#  15  cat_Streets_and_Roadways                134 non-null    uint8
#  16  cat_Wastewater_Treatment                134 non-null    uint8
#  17  cat_Water_Supply                        134 non-null    uint8
#  18  manag_DCAS                              134 non-null    uint8
#  19  manag_DDC                               134 non-null    uint8
#  20  manag_DEP                               134 non-null    uint8
#  21  manag_DOT                               134 non-null    uint8
#  22  manag_EDC                               134 non-null    uint8
#  23  manag_SCA                               134 non-null    uint8
#  24  cliag_BWS                               134 non-null    uint8
#  25  cliag_DCAS                              134 non-null    uint8
#  26  cliag_DCLA                              134 non-null    uint8
#  27  cliag_DEP                               134 non-null    uint8
#  28  cliag_DEP,_EDC                          134 non-null    uint8
#  29  cliag_DHS                               134 non-null    uint8
#  30  cliag_DOE                               134 non-null    uint8
#  31  cliag_DOHMH,_HHC                        134 non-null    uint8
#  32  cliag_DOT                               134 non-null    uint8
#  33  cliag_DOT,_Mayor's_Office               134 non-null    uint8
#  34  cliag_DPR                               134 non-null    uint8
#  35  cliag_DSBS                              134 non-null    uint8
#  36  cliag_DSNY                              134 non-null    uint8
#  37  cliag_EDC                               134 non-null    uint8
#  38  cliag_H+H                               134 non-null    uint8
#  39  cliag_Mayor's_Office                    134 non-null    uint8
#  40  cliag_NYPD                              134 non-null    uint8
#  41  cliag_ORR                               134 non-null    uint8
#  42  bor_Bronx                               134 non-null    uint8
#  43  bor_Brooklyn                            134 non-null    uint8
#  44  bor_Brooklyn,_Queens                    134 non-null    uint8
#  45  bor_Citywide                            134 non-null    uint8
#  46  bor_Manhattan                           134 non-null    uint8
#  47  bor_Manhattan,_Bronx                    134 non-null    uint8
#  48  bor_Manhattan,_Staten_Island,_Bronx     134 non-null    uint8
#  49  bor_Marlboro                            134 non-null    uint8
#  50  bor_New_York                            134 non-null    uint8
#  51  bor_Olive                               134 non-null    uint8
#  52  bor_Port_Jervis                         134 non-null    uint8
#  53  bor_Queens                              134 non-null    uint8
#  54  bor_Staten_Island                       134 non-null    uint8
#  55  bor_Valhalla                            134 non-null    uint8
#  56  2-Design                                134 non-null    uint8
#  57  3-Construction_Procurement              134 non-null    uint8
# dtypes: float64(1), int64(1), uint8(56)
# memory usage: 10.5 KB

# %%
#######################################
# CREATE SCALED DATAFRAMES
#######################################

# Identify binary variable columns to exclude from scaling
exclude_scale_cols = list(X)[2:]

# # Reset y dataframe indices or else we will run into indexing issues
# y_train = y_train.reset_index(drop=True)
# y_test = y_test.reset_index(drop=True)


# Standardize both X_train and X_test data, fitting X_train as the
# scaler for both
scaler = StandardScaler
scale_before_func = None
scale_after_func = None
reapply_scaler = False


X_train_std, Scaler_std = scale_features(
    X_train, X_train,
    exclude_scale_cols,
    scaler,
    scale_before_func,
    scale_after_func,
    reapply_scaler,
)

X_test_std, _ = scale_features(
    X_train, X_test,
    exclude_scale_cols,
    scaler,
    scale_before_func,
    scale_after_func,
    reapply_scaler,
)


# Standardize X_train and X_test, pass through sigmoid transformation
# and re-standardize to minimize skew of data
scaler = StandardScaler
scale_before_func = None
scale_after_func = sigmoid
reapply_scaler = True


X_train_std_sig, Scaler_std_sig = scale_features(
    X_train, X_train,
    exclude_scale_cols,
    scaler,
    scale_before_func,
    scale_after_func,
    reapply_scaler,
)

X_test_std_sig, _ = scale_features(
    X_train, X_test,
    exclude_scale_cols,
    scaler,
    scale_before_func,
    scale_after_func,
    reapply_scaler,
)

# %%
# inspect scaled datasets
plot_bdgt_sched_scaled(X_train, X_train_std, 'Standardized', X_test, X_test_std)
plot_bdgt_sched_scaled(X_train, X_train_std_sig, 'Sigmoid standardized', X_test, X_test_std_sig)
# Out:
# /home/sedelmeyer/.local/share/virtualenvs/nyc-capital-projects-nSoXLpsW/lib/python3.7/site-packages/numpy/lib/function_base.py:2559: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/sedelmeyer/.local/share/virtualenvs/nyc-capital-projects-nSoXLpsW/lib/python3.7/site-packages/numpy/lib/function_base.py:2560: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %% [markdown]
# # Inspect k-means clustering
#
# [Return to top](#Contents-of-this-notebook)
#
# ### Start by running through a range of k-clusters to identify optimal clustering performance

# %%
# %%time

n_init = 40
random_state = 109

# define version of X scaled data to use throughout the remaining cells
X_data = X_train_std_sig

# define list of k values to compare
k_list = list(np.arange(1,25))

# fit kmeans at each value k and save to dict for future use
# reuse the same n_init=46 and random_state=109 values used previously
kmeans_dict = {
    k: KMeans(n_clusters=k, n_init=n_init, random_state=random_state).fit(X_data)
    for k in k_list
}

# save total within-cluster variation for each kmeans fit
tot_var_vals = [kfit.inertia_ for kfit in kmeans_dict.values()]
# Out:
# CPU times: user 4.6 s, sys: 463 ms, total: 5.07 s
# Wall time: 4.35 s

# %%
# set my plot parameters and generate my elbow plot
y_vals = tot_var_vals
x_vals = k_list
title = 'Total within-cluster variation ($T_k$) vs. number of clusters'
x_label = 'number of clusters $K$'
y_label = 'interia'

plot_line(x_vals, y_vals, title, x_label, y_label)

# %%
# save average silhouette score for each kmeans fit
# handle k=1 silhouette score error by inputting 0 as start to list
silscore_vals = [0] + [
    silhouette_score(X_data, kmeans_dict[k].labels_)
    for k in k_list[1:]
]

# %%
# set my plot parameters and generate my avg. silhouette score plot
y_vals = silscore_vals
x_vals = k_list
title = 'Average silhouette score vs. number of clusters'
x_label = 'number of clusters $K$'
y_label = 'average silhouette'

plot_line(x_vals, y_vals, title, x_label, y_label)

# %%
# %%time
# Initialize OptimalK object
gs_obj = OptimalK()

# Provide OptimalK object with dataset and cluster array
n_clusters = gs_obj(X_data.values, n_refs=200, cluster_array=k_list)

print('Optimal clusters given estimated gap value: {}\n'.format(n_clusters))
# Out:
# Optimal clusters given estimated gap value: 22
#
# CPU times: user 130 ms, sys: 77.5 ms, total: 208 ms
# Wall time: 2.78 s

# %%
# Plot Gap statistic results for interpretation
gs_obj.plot_results()

# Plot Gap statistic with error bars
display_gapstat_with_errbars(gs_obj.gap_df)

# %%
# %%time

# try with 2 clusters
n_classes = 2
n_init = 100

# fit kmeans algorithm and save to Cluster5 column in df
km_cluster2 = KMeans(
    n_clusters=n_classes, n_init=n_init, random_state=random_state
).fit(X_data)

cluster_labels = km_cluster2.labels_

silhouette_avg = silhouette_score(X_data, cluster_labels)

centers = silplot(X_data, cluster_labels, km_cluster2)


# try with 3 clusters
n_classes = 3
n_init = 100

# fit kmeans algorithm and save to Cluster5 column in df
km_cluster3 = KMeans(
    n_clusters=n_classes, n_init=n_init, random_state=random_state
).fit(X_data)

cluster_labels = km_cluster3.labels_

silhouette_avg = silhouette_score(X_data, cluster_labels)

centers = silplot(X_data, cluster_labels, km_cluster3)


# try with 5 clusters
n_classes = 5

# fit kmeans algorithm and save to Cluster5 column in df
km_cluster5 = KMeans(
    n_clusters=n_classes, n_init=n_init, random_state=random_state
).fit(X_data)

cluster_labels = km_cluster5.labels_

silhouette_avg = silhouette_score(X_data, cluster_labels)

centers = silplot(X_data, cluster_labels, km_cluster5)
# Out:
# CPU times: user 3.73 s, sys: 1.7 s, total: 5.42 s
# Wall time: 2.4 s

# %% [markdown]
# # Check results against DBSCAN
#
# [Return to top](#Contents-of-this-notebook)

# %%
# %%time
# Use general rule of thumb presented in class where min_samples
# is set to the number of features (12) x 2
min_samples = 12 # 54 * 2

# Use knn to plot and identify suitable epsilon values for DBSCAN
distances = fit_neighbors(X_data, min_samples)
plot_epsilon(distances, min_samples)
# Out:
# CPU times: user 314 ms, sys: 121 ms, total: 435 ms
# Wall time: 242 ms

# %%
# %%time

eps = 2.25

dbscan = fit_dbscan(X_data, min_samples, eps)

print_dbscan_results(dbscan)
# Out:
# For the DBSCAN model:
#
# DBSCAN(eps=2.25, min_samples=12)
#
# 2 clusters were identified, and 25 of the n=134 observations were not assigned to any clusters.
#
# The distribution of resulting labels are illustrated by this chart with un-clustered observations represented by the cluster labeled -1.
#
#
# The resulting silhouette score, excluding the points not assigned to any cluster is:
#
# 	0.1843
#
# CPU times: user 62.4 ms, sys: 12.7 ms, total: 75.1 ms
# Wall time: 31.9 ms

# %% [markdown]
# # Check results against a Ward Method Dendrogram
#
# [Return to top](#Contents-of-this-notebook)

# %%
# %%time

# generate distance matrix
dist_mat = pdist(X_data, metric="euclidean")

# perform wards linkage on distance matrix
ward_data = hac.ward(dist_mat)

# generate dendrogram and plot it
plt.figure(figsize=(11, 8.5))

hac.dendrogram(ward_data, above_threshold_color='lightgray', orientation="top");

plt.title("Agglomerative clustering dendrogram (using Ward's method)", fontsize=20)
plt.grid(":", axis='y', alpha=0.4)
plt.yticks(np.arange(0, 16, 1), fontsize=10)
plt.ylabel('distance', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# CPU times: user 3.45 s, sys: 541 ms, total: 3.99 s
# Wall time: 3.61 s

# %%
# generate list of distance thresholds (t) to evaluate
t_list = np.arange(1, 16, 1)

# generate disctionary of cluster lables for each value t
label_dict = {
    t: hac.fcluster(ward_data, t=t, criterion='distance')
    for t in t_list
}

# calculate silhouette scores for each set of labels
sil_scores = [
    silhouette_score(X_data, labellings)
    for labellings in label_dict.values()
]

# generate list of cluster counts for each set of labels
cluster_counts =[
    len(set(labellings)) for labellings in label_dict.values()
]

# %%
y_vals = sil_scores
x_vals = t_list
title = 'Average silhouette score vs. agglomerative distance threshold $t$'
x_label = 'distance threshold $t$'
y_label = 'average silhouette'

plot_line(x_vals, y_vals, title, x_label, y_label)

# y_vals = sil_scores
# x_vals = cluster_counts
# title = 'Average silhouette score vs. agglomerative cluster count'
# x_label = 'number of clusters'
# y_label = 'average silhouette'

# plot_line(x_vals, y_vals, title, x_label, y_label)

y_vals = cluster_counts
x_vals = t_list
title = 'Agglomerative cluster count vs. distance threshold $t$'
x_label = 'distance threshold $t$'
y_label = 'number of clusters'

plot_line(x_vals, y_vals, title, x_label, y_label)

max_sil = np.max(sil_scores)
max_idx = np.argmax(sil_scores)
max_sil_clust = cluster_counts[max_idx]
max_sil_thresh = t_list[max_idx]


print(
    '\nThe maximum silhouette score of {:.3f}, suggests K={} clusters at threshold t={:,}.\n'\
    ''.format(
        max_sil, max_sil_clust, max_sil_thresh,
    )
)
# Out:
# The maximum silhouette score of 0.340, suggests K=2 clusters at threshold t=12.

# %% [markdown]
# # Findings
#
# [Return to top](#Contents-of-this-notebook)
#
# - DBSCAN was difficult to get any clustering
# - Dendrogram and Kmeans algrorithms appear to support a $k=3$ cluster grouping

# %%
km3_test = km_cluster3.predict(X_test_std_sig)
km3_train = km_cluster3.predict(X_train_std_sig)

# %%
df_km3_train = pd.DataFrame(
    np.hstack(
        [
            X_train.index.values.reshape(-1,1),
            km3_train.reshape(-1,1)
        ]
    ),
    columns = ['PID', 'attribute_km3_label']
)


df_km3_test = pd.DataFrame(
    np.hstack(
        [
            X_test.index.values.reshape(-1,1),
            km3_test.reshape(-1,1)
        ]
    ),
    columns = ['PID', 'attribute_km3_label']
)

df_km3_train.shape, df_km3_test.shape
# Out:
# ((134, 2), (15, 2))

# %%
df_km3_train.info()
df_km3_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PID                  134 non-null    int64
#  1   attribute_km3_label  134 non-null    int64
# dtypes: int64(2)
# memory usage: 2.2 KB
#    PID  attribute_km3_label
# 0  204                    0
# 1  577                    1
# 2  664                    0
# 3  402                    2
# 4  760                    0

# %% [markdown]
# # Save resulting k-means labels and model
#
# [Return to top](#Contents-of-this-notebook)

# %%
# save finalized encodings dataframes to .csv
df_km3_train.to_csv(savedata_train, index=False)
df_km3_test.to_csv(savedata_test, index=False)

# save fitted sklearn Kmeans model using pickle
pickle.dump(km_cluster3, open(savemodel, 'wb'))
